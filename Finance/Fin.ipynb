# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
lit = pd.read_csv('./data1/LIT.csv')

# %%
lit.head(3)
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2021-09-07  85.000000  85.349998  84.830002  85.040001  84.821106  1047600
# 1  2021-09-08  84.970001  85.089996  83.400002  83.980003  83.763832   707400
# 2  2021-09-09  83.980003  85.430000  83.980003  84.839996  84.621620   500100

# %%
lit['Date'] = pd.to_datetime(lit['Date'])

# %%
lit['min_max_gain'] = lit['High'] - lit['Close']
lit
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2021-09-07  85.000000  85.349998  84.830002  85.040001  84.821106
# 1   2021-09-08  84.970001  85.089996  83.400002  83.980003  83.763832
# 2   2021-09-09  83.980003  85.430000  83.980003  84.839996  84.621620
# 3   2021-09-10  85.830002  86.699997  85.040001  85.129997  84.910866
# 4   2021-09-13  85.129997  85.349998  83.000000  83.709999  83.494530
# ..         ...        ...        ...        ...        ...        ...
# 246 2022-08-29  76.000000  76.889999  75.760002  76.269997  76.269997
# 247 2022-08-30  76.599998  76.739998  74.320000  74.639999  74.639999
# 248 2022-08-31  74.660004  74.660004  73.769997  73.769997  73.769997
# 249 2022-09-01  73.129997  73.129997  71.309998  72.279999  72.279999
# 250 2022-09-02  72.300003  72.669998  71.529999  71.720001  71.720001
#
#       Volume  min_max_gain
# 0    1047600      0.309997
# 1     707400      1.109993
# 2     500100      0.590004
# ...

# %%
Y = 'min_max_gain'
sns.lineplot(data=lit,x='Date',y=Y)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='min_max_gain'>

# %%
sns.histplot(data=lit,x='min_max_gain')
# Out:
# <AxesSubplot:xlabel='min_max_gain', ylabel='Count'>

# %%
sns.relplot(data=lit,x='Volume',y='min_max_gain',hue='Close')

# %%
sns.relplot(data=lit,x='Volume',y='Close',hue='min_max_gain')

# %%
sns.lmplot(data=lit,x='Volume',y='Close')
